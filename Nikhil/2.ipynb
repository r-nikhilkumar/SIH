# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn import linear_model, datasets
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, accuracy_score, precision_score, recall_score
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier

# %%
data = pd.read_csv("dataset.csv")

# %%
ar = ["Symptom_1","Symptom_2","Symptom_3","Symptom_4","Symptom_5","Symptom_6","Symptom_7","Symptom_8","Symptom_9","Symptom_10","Symptom_11","Symptom_12","Symptom_13","Symptom_14","Symptom_15","Symptom_16","Symptom_17"]

# %%
l = 0
st = set()
for m in ar:
    j=1
    data[ar[l]].fillna("nothing",inplace = True)
    s = data[ar[l]].unique()
    l+=1
    for i in s:
        st.add(i)
dict = {}
n=1
for i in st:
    if(i=="nothing"):
        dict[i] = 0
    else:
        dict[i] = n
        n+=1
dict
# Out:
# {' family_history': 1,
#  ' altered_sensorium': 2,
#  ' redness_of_eyes': 3,
#  ' back_pain': 4,
#  ' pain_behind_the_eyes': 5,
#  ' bruising': 6,
#  ' red_spots_over_body': 7,
#  ' high_fever': 8,
#  ' patches_in_throat': 9,
#  ' history_of_alcohol_consumption': 10,
#  ' rusty_sputum': 11,
#  ' toxic_look_(typhos)': 12,
#  ' chills': 13,
#  ' burning_micturition': 14,
#  ' fast_heart_rate': 15,
#  ' small_dents_in_nails': 16,
#  ' weight_loss': 17,
#  ' indigestion': 18,
#  ' stomach_bleeding': 19,
#  ' weakness_of_one_body_side': 20,
#  ' swollen_blood_vessels': 21,
#  ' vomiting': 22,
#  ' pain_in_anal_region': 23,
#  ' headache': 24,
#  ' mucoid_sputum': 25,
#  ' polyuria': 26,
#  ' dischromic _patches': 27,
#  ' loss_of_balance': 28,
#  ' loss_of_smell': 29,
#  ' malaise': 30,
#  ' mild_fever': 31,
#  ' phlegm': 32,
#  ' depression': 33,
#  ' inflammatory_nails': 34,
#  ' obesity': 35,
#  ' passage_of_gases': 36,
#  ' enlarged_thyroid': 37,
#  ' increased_appetite': 38,
#  ' palpitations': 39,
#  ' slurred_speech': 40,
#  ' receiving_blood_transfusion': 41,
#  ' weakness_in_limbs': 42,
#  ' skin_peeling': 43,
#  ' yellowing_of_eyes': 44,
#  ' belly_pain': 45,
#  ' silver_like_dusting': 46,
#  ' throat_irritation': 47,
#  ' red_sore_around_nose': 48,
#  ' excessive_hunger': 49,
#  ' knee_pain': 50,
#  ' extra_marital_contacts': 51,
#  ' swollen_legs': 52,
#  ' muscle_wasting': 53,
#  ' blackheads': 54,
#  ' muscle_pain': 55,
#  ' visual_disturbances': 56,
#  ' sweating': 57,
#  ' blood_in_sputum': 58,
#  ' irregular_sugar_level': 59,
#  ' congestion': 60,
#  ' stomach_pain': 61,
#  ' skin_rash': 62,
#  ' foul_smell_of urine': 63,
#  ' restlessness': 64,
#  ' irritation_in_anus': 65,
#  ' bloody_stool': 66,
#  ' joint_pain': 67,
#  ' hip_joint_pain': 68,
#  ' weight_gain': 69,
#  ' stiff_neck': 70,
#  ' movement_stiffness': 71,
#  ' irritability': 72,
#  ' unsteadiness': 73,
#  ' fatigue': 74,
#  ' bladder_discomfort': 75,
#  ' swelling_of_stomach': 76,
#  ' dark_urine': 77,
#  ' brittle_nails': 78,
#  ' lack_of_concentration': 79,
#  ' prominent_veins_on_calf': 80,
#  ' loss_of_appetite': 81,
#  ' breathlessness': 82,
#  ' lethargy': 83,
#  ' abnormal_menstruation': 84,
#  ' cough': 85,
#  ' runny_nose': 86,
#  ' chest_pain': 87,
#  ' dehydration': 88,
#  ' fluid_overload': 89,
#  ' constipation': 90,
#  ' receiving_unsterile_injections': 91,
#  'itching': 92,
#  ' mood_swings': 93,
#  ' continuous_sneezing': 94,
#  ' muscle_weakness': 95,
#  ' swollen_extremeties': 96,
#  ' puffy_face_and_eyes': 97,
#  ' spinning_movements': 98,
#  ' drying_and_tingling_lips': 99,
#  ' nodal_skin_eruptions': 100,
#  ' sinus_pressure': 101,
#  ' pus_filled_pimples': 102,
#  ' ulcers_on_tongue': 103,
#  ' painful_walking': 104,
#  ' cramps': 105,
#  ' swelled_lymph_nodes': 106,
#  ' blurred_and_distorted_vision': 107,
#  ' yellowish_skin': 108,
#  ' acute_liver_failure': 109,
#  ' pain_during_bowel_movements': 110,
#  ' dizziness': 111,
#  ' distention_of_abdomen': 112,
#  ' sunken_eyes': 113,
#  ' cold_hands_and_feets': 114,
#  ' yellow_crust_ooze': 115,
#  ' yellow_urine': 116,
#  ' nausea': 117,
#  ' internal_itching': 118,
#  ' abdominal_pain': 119,
#  ' scurring': 120,
#  'nothing': 0,
#  ' swelling_joints': 121,
#  ' coma': 122,
#  ' shivering': 123,
#  ' acidity': 124,
#  ' diarrhoea': 125,
#  ' blister': 126,
#  ' neck_pain': 127,
#  ' anxiety': 128,
#  ' watering_from_eyes': 129,
#  ' continuous_feel_of_urine': 130,
#  ' spotting_ urination': 131}

# %%
k=0
for i in ar:
    data[i].replace(dict, inplace=True)
data
for i in data:
    print(data[i])
    input()
# Out:
# 0                              Fungal infection
# 1                              Fungal infection
# 2                              Fungal infection
# 3                              Fungal infection
# 4                              Fungal infection
#                          ...
# 4915    (vertigo) Paroymsal  Positional Vertigo
# 4916                                       Acne
# 4917                    Urinary tract infection
# 4918                                  Psoriasis
# 4919                                   Impetigo
# Name: Disease, Length: 4920, dtype: object
# 0       92
# 1       62
# 2       92
# 3       92
# 4       92
#         ..
# 4915    22
# 4916    62
# 4917    14
# 4918    62
# 4919    62
# Name: Symptom_1, Length: 4920, dtype: int64
# 0        62
# 1       100
# 2       100
# 3        62
# 4        62
#        ...
# 4915     24
# 4916    102
# 4917     75
# 4918     67
# 4919      8
# Name: Symptom_2, Length: 4920, dtype: int64
# 0       100
# 1        27
# 2        27
# 3        27
# 4       100
#        ...
# 4915    117
# 4916     54
# 4917     63
# 4918     43
# 4919    126
# Name: Symptom_3, Length: 4920, dtype: int64
# 0        27
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 4915     98
# 4916    120
# 4917    130
# 4918     46
# 4919     48
# Name: Symptom_4, Length: 4920, dtype: int64
# 0         0
# 1         0
# 2         0
# 3         0
# 4         0
#        ...
# 4915     28
# 4916      0
# 4917      0
# 4918     16
# 4919    115
# Name: Symptom_5, Length: 4920, dtype: int64
# 0        0
# 1        0
# 2        0
# 3        0
# 4        0
#         ..
# 4915    73
# 4916     0
# 4917     0
# 4918    34
# 4919     0
# Name: Symptom_6, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_7, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_8, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_9, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_10, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_11, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_12, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_13, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_14, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_15, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_16, Length: 4920, dtype: int64
# 0       0
# 1       0
# 2       0
# 3       0
# 4       0
#        ..
# 4915    0
# 4916    0
# 4917    0
# 4918    0
# 4919    0
# Name: Symptom_17, Length: 4920, dtype: int64
